# %% [markdown]
# ## Import Python Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Import Data

# %% [markdown]
# #### import only first table to check it

# %%
tripdata_202207_df = pd.read_csv('data/202207-divvy-tripdata.csv')

# %%
tripdata_202207_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  954144C2F67B1932  classic_bike  2022-07-05 08:12:47  2022-07-05 08:24:32
# 1  292E027607D218B6  classic_bike  2022-07-26 12:53:38  2022-07-26 12:55:31
# 2  57765852588AD6E0  classic_bike  2022-07-03 13:58:49  2022-07-03 14:06:32
# 3  B5B6BE44314590E6  classic_bike  2022-07-31 17:44:21  2022-07-31 18:42:50
# 4  A4C331F2A00E79E0  classic_bike  2022-07-13 19:49:06  2022-07-13 20:15:24
#
#            start_station_name start_station_id  \
# 0  Ashland Ave & Blackhawk St            13224
# 1  Buckingham Fountain (Temp)            15541
# 2  Buckingham Fountain (Temp)            15541
# 3  Buckingham Fountain (Temp)            15541
# 4      Wabash Ave & Grand Ave     TA1307000117
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0        Kingsbury St & Kinzie St   KA1503000043  41.907066 -87.667252
# 1           Michigan Ave & 8th St            623  41.869621 -87.623981
# ...

# %%
tripdata_202207_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823488 entries, 0 to 823487
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             823488 non-null  object
#  1   rideable_type       823488 non-null  object
#  2   started_at          823488 non-null  object
#  3   ended_at            823488 non-null  object
#  4   start_station_name  711457 non-null  object
#  5   start_station_id    711457 non-null  object
#  6   end_station_name    702537 non-null  object
#  7   end_station_id      702537 non-null  object
#  8   start_lat           823488 non-null  float64
#  9   start_lng           823488 non-null  float64
#  10  end_lat             822541 non-null  float64
#  11  end_lng             822541 non-null  float64
#  12  member_casual       823488 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 81.7+ MB

# %% [markdown]
# #### Import the rest of the tables and preview each one to check if there any problem in it like missing column

# %%
tripdata_202206_df = pd.read_csv('data/202206-divvy-tripdata.csv')
tripdata_202205_df = pd.read_csv('data/202205-divvy-tripdata.csv')
tripdata_202204_df = pd.read_csv('data/202204-divvy-tripdata.csv')
tripdata_202203_df = pd.read_csv('data/202203-divvy-tripdata.csv')
tripdata_202202_df = pd.read_csv('data/202202-divvy-tripdata.csv')
tripdata_202201_df = pd.read_csv('data/202201-divvy-tripdata.csv')
tripdata_202112_df = pd.read_csv('data/202112-divvy-tripdata.csv')
tripdata_202111_df = pd.read_csv('data/202111-divvy-tripdata.csv')
tripdata_202110_df = pd.read_csv('data/202110-divvy-tripdata.csv')
tripdata_202109_df = pd.read_csv('data/202109-divvy-tripdata.csv')
tripdata_202108_df = pd.read_csv('data/202108-divvy-tripdata.csv')

# %%
tripdata_202206_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  600CFD130D0FD2A4  electric_bike  2022-06-30 17:27:53  2022-06-30 17:35:15
# 1  F5E6B5C1682C6464  electric_bike  2022-06-30 18:39:52  2022-06-30 18:47:28
# 2  B6EB6D27BAD771D2  electric_bike  2022-06-30 11:49:25  2022-06-30 12:02:54
# 3  C9C320375DE1D5C6  electric_bike  2022-06-30 11:15:25  2022-06-30 11:19:43
# 4  56C055851023BE98  electric_bike  2022-06-29 23:36:50  2022-06-29 23:45:17
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
tripdata_202206_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 769204 entries, 0 to 769203
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             769204 non-null  object
#  1   rideable_type       769204 non-null  object
#  2   started_at          769204 non-null  object
#  3   ended_at            769204 non-null  object
#  4   start_station_name  676260 non-null  object
#  5   start_station_id    676260 non-null  object
#  6   end_station_name    669052 non-null  object
#  7   end_station_id      669052 non-null  object
#  8   start_lat           769204 non-null  float64
#  9   start_lng           769204 non-null  float64
#  10  end_lat             768149 non-null  float64
#  11  end_lng             768149 non-null  float64
#  12  member_casual       769204 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 76.3+ MB

# %%
tripdata_202205_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  EC2DE40644C6B0F4  classic_bike  2022-05-23 23:06:58  2022-05-23 23:40:19
# 1  1C31AD03897EE385  classic_bike  2022-05-11 08:53:28  2022-05-11 09:31:22
# 2  1542FBEC830415CF  classic_bike  2022-05-26 18:36:28  2022-05-26 18:58:18
# 3  6FF59852924528F8  classic_bike  2022-05-10 07:30:07  2022-05-10 07:38:49
# 4  483C52CAAE12E3AC  classic_bike  2022-05-10 17:31:56  2022-05-10 17:36:57
#
#                   start_station_name start_station_id  \
# 0             Wabash Ave & Grand Ave     TA1307000117
# 1  DuSable Lake Shore Dr & Monroe St            13300
# 2            Clinton St & Madison St     TA1305000032
# 3            Clinton St & Madison St     TA1305000032
# 4            Clinton St & Madison St     TA1305000032
#
#               end_station_name end_station_id  start_lat  start_lng  \
# 0       Halsted St & Roscoe St   TA1309000025  41.891466 -87.626761
# ...

# %%
tripdata_202205_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634858 entries, 0 to 634857
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             634858 non-null  object
#  1   rideable_type       634858 non-null  object
#  2   started_at          634858 non-null  object
#  3   ended_at            634858 non-null  object
#  4   start_station_name  548154 non-null  object
#  5   start_station_id    548154 non-null  object
#  6   end_station_name    541687 non-null  object
#  7   end_station_id      541687 non-null  object
#  8   start_lat           634858 non-null  float64
#  9   start_lng           634858 non-null  float64
#  10  end_lat             634136 non-null  float64
#  11  end_lng             634136 non-null  float64
#  12  member_casual       634858 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 63.0+ MB

# %%
tripdata_202204_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  3564070EEFD12711  electric_bike  2022-04-06 17:42:48  2022-04-06 17:54:36
# 1  0B820C7FCF22F489   classic_bike  2022-04-24 19:23:07  2022-04-24 19:43:17
# 2  89EEEE32293F07FF   classic_bike  2022-04-20 19:29:08  2022-04-20 19:35:16
# 3  84D4751AEB31888D   classic_bike  2022-04-22 21:14:06  2022-04-22 21:23:29
# 4  5664BCF0D1DE7A8B  electric_bike  2022-04-16 15:56:30  2022-04-16 16:02:11
#
#           start_station_name start_station_id          end_station_name  \
# 0     Paulina St & Howard St              515   University Library (NU)
# 1  Wentworth Ave & Cermak Rd            13075     Green St & Madison St
# 2       Halsted St & Polk St     TA1307000121     Green St & Madison St
# 3  Wentworth Ave & Cermak Rd            13075  Delano Ct & Roosevelt Rd
# 4       Halsted St & Polk St     TA1307000121   Clinton St & Madison St
#
# ...

# %%
tripdata_202204_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371249 entries, 0 to 371248
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             371249 non-null  object
#  1   rideable_type       371249 non-null  object
#  2   started_at          371249 non-null  object
#  3   ended_at            371249 non-null  object
#  4   start_station_name  300362 non-null  object
#  5   start_station_id    300362 non-null  object
#  6   end_station_name    295961 non-null  object
#  7   end_station_id      295961 non-null  object
#  8   start_lat           371249 non-null  float64
#  9   start_lng           371249 non-null  float64
#  10  end_lat             370932 non-null  float64
#  11  end_lng             370932 non-null  float64
#  12  member_casual       371249 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 36.8+ MB

# %%
tripdata_202203_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  47EC0A7F82E65D52   classic_bike  2022-03-21 13:45:01  2022-03-21 13:51:18
# 1  8494861979B0F477  electric_bike  2022-03-16 09:37:16  2022-03-16 09:43:34
# 2  EFE527AF80B66109   classic_bike  2022-03-23 19:52:02  2022-03-23 19:54:48
# 3  9F446FD9DEE3F389   classic_bike  2022-03-01 19:12:26  2022-03-01 19:22:14
# 4  431128AD9AFFEDC0   classic_bike  2022-03-21 18:37:01  2022-03-21 19:19:11
#
#                    start_station_name start_station_id  \
# 0              Wabash Ave & Wacker Pl     TA1307000131
# 1               Michigan Ave & Oak St            13042
# 2               Broadway & Berwyn Ave            13109
# 3              Wabash Ave & Wacker Pl     TA1307000131
# 4  DuSable Lake Shore Dr & North Blvd           LF-005
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0              Kingsbury St & Kinzie St   KA1503000043  41.886875 -87.626030
# ...

# %%
tripdata_202203_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284042 entries, 0 to 284041
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             284042 non-null  object
#  1   rideable_type       284042 non-null  object
#  2   started_at          284042 non-null  object
#  3   ended_at            284042 non-null  object
#  4   start_station_name  236796 non-null  object
#  5   start_station_id    236796 non-null  object
#  6   end_station_name    232885 non-null  object
#  7   end_station_id      232885 non-null  object
#  8   start_lat           284042 non-null  float64
#  9   start_lng           284042 non-null  float64
#  10  end_lat             283776 non-null  float64
#  11  end_lng             283776 non-null  float64
#  12  member_casual       284042 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 28.2+ MB

# %%
tripdata_202202_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  E1E065E7ED285C02  classic_bike  2022-02-19 18:08:41  2022-02-19 18:23:56
# 1  1602DCDC5B30FFE3  classic_bike  2022-02-20 17:41:30  2022-02-20 17:45:56
# 2  BE7DD2AF4B55C4AF  classic_bike  2022-02-25 18:55:56  2022-02-25 19:09:34
# 3  A1789BDF844412BE  classic_bike  2022-02-14 11:57:03  2022-02-14 12:04:00
# 4  07DE78092C62F7B3  classic_bike  2022-02-16 05:36:06  2022-02-16 05:39:00
#
#              start_station_name start_station_id  \
# 0        State St & Randolph St     TA1305000029
# 1   Halsted St & Wrightwood Ave     TA1309000061
# 2        State St & Randolph St     TA1305000029
# 3  Southport Ave & Waveland Ave            13235
# 4        State St & Randolph St     TA1305000029
#
#                  end_station_name end_station_id  start_lat  start_lng  \
# 0          Clark St & Lincoln Ave          13179  41.884621 -87.627834
# ...

# %%
tripdata_202202_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115609 entries, 0 to 115608
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             115609 non-null  object
#  1   rideable_type       115609 non-null  object
#  2   started_at          115609 non-null  object
#  3   ended_at            115609 non-null  object
#  4   start_station_name  97029 non-null   object
#  5   start_station_id    97029 non-null   object
#  6   end_station_name    95254 non-null   object
#  7   end_station_id      95254 non-null   object
#  8   start_lat           115609 non-null  float64
#  9   start_lng           115609 non-null  float64
#  10  end_lat             115532 non-null  float64
#  11  end_lng             115532 non-null  float64
#  12  member_casual       115609 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 11.5+ MB

# %%
tripdata_202201_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  C2F7DD78E82EC875  electric_bike  2022-01-13 11:59:47  2022-01-13 12:02:44
# 1  A6CF8980A652D272  electric_bike  2022-01-10 08:41:56  2022-01-10 08:46:17
# 2  BD0F91DFF741C66D   classic_bike  2022-01-25 04:53:40  2022-01-25 04:58:01
# 3  CBB80ED419105406   classic_bike  2022-01-04 00:18:04  2022-01-04 00:33:00
# 4  DDC963BFDDA51EEA   classic_bike  2022-01-20 01:31:10  2022-01-20 01:37:12
#
#               start_station_name start_station_id  \
# 0       Glenwood Ave & Touhy Ave              525
# 1       Glenwood Ave & Touhy Ave              525
# 2  Sheffield Ave & Fullerton Ave     TA1306000016
# 3       Clark St & Bryn Mawr Ave     KA1504000151
# 4    Michigan Ave & Jackson Blvd     TA1309000002
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0           Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# ...

# %%
tripdata_202201_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103770 entries, 0 to 103769
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             103770 non-null  object
#  1   rideable_type       103770 non-null  object
#  2   started_at          103770 non-null  object
#  3   ended_at            103770 non-null  object
#  4   start_station_name  87510 non-null   object
#  5   start_station_id    87510 non-null   object
#  6   end_station_name    85843 non-null   object
#  7   end_station_id      85843 non-null   object
#  8   start_lat           103770 non-null  float64
#  9   start_lng           103770 non-null  float64
#  10  end_lat             103684 non-null  float64
#  11  end_lng             103684 non-null  float64
#  12  member_casual       103770 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 10.3+ MB

# %%
tripdata_202112_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  46F8167220E4431F  electric_bike  2021-12-07 15:06:07  2021-12-07 15:13:42
# 1  73A77762838B32FD  electric_bike  2021-12-11 03:43:29  2021-12-11 04:10:23
# 2  4CF42452054F59C5  electric_bike  2021-12-15 23:10:28  2021-12-15 23:23:14
# 3  3278BA87BF698339   classic_bike  2021-12-26 16:16:10  2021-12-26 16:30:53
# 4  6FF54232576A3B73  electric_bike  2021-12-30 11:31:05  2021-12-30 11:51:21
#
#              start_station_name start_station_id            end_station_name  \
# 0      Laflin St & Cullerton St            13307         Morgan St & Polk St
# 1         LaSalle Dr & Huron St     KP1705001026  Clarendon Ave & Leland Ave
# 2  Halsted St & North Branch St     KA1504000117        Broadway & Barry Ave
# 3  Halsted St & North Branch St     KA1504000117       LaSalle Dr & Huron St
# 4      Leavitt St & Chicago Ave            18058      Clark St & Drummond Pl
#
# ...

# %%
tripdata_202112_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247540 entries, 0 to 247539
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             247540 non-null  object
#  1   rideable_type       247540 non-null  object
#  2   started_at          247540 non-null  object
#  3   ended_at            247540 non-null  object
#  4   start_station_name  196477 non-null  object
#  5   start_station_id    196477 non-null  object
#  6   end_station_name    194042 non-null  object
#  7   end_station_id      194042 non-null  object
#  8   start_lat           247540 non-null  float64
#  9   start_lng           247540 non-null  float64
#  10  end_lat             247396 non-null  float64
#  11  end_lng             247396 non-null  float64
#  12  member_casual       247540 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 24.6+ MB

# %%
tripdata_202111_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  7C00A93E10556E47  electric_bike  2021-11-27 13:27:38  2021-11-27 13:46:38
# 1  90854840DFD508BA  electric_bike  2021-11-27 13:38:25  2021-11-27 13:56:10
# 2  0A7D10CDD144061C  electric_bike  2021-11-26 22:03:34  2021-11-26 22:05:56
# 3  2F3BE33085BCFF02  electric_bike  2021-11-27 09:56:49  2021-11-27 10:01:50
# 4  D67B4781A19928D4  electric_bike  2021-11-26 19:09:28  2021-11-26 19:30:41
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
tripdata_202111_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359978 entries, 0 to 359977
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             359978 non-null  object
#  1   rideable_type       359978 non-null  object
#  2   started_at          359978 non-null  object
#  3   ended_at            359978 non-null  object
#  4   start_station_name  284688 non-null  object
#  5   start_station_id    284688 non-null  object
#  6   end_station_name    280791 non-null  object
#  7   end_station_id      280791 non-null  object
#  8   start_lat           359978 non-null  float64
#  9   start_lng           359978 non-null  float64
#  10  end_lat             359787 non-null  float64
#  11  end_lng             359787 non-null  float64
#  12  member_casual       359978 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 35.7+ MB

# %%
tripdata_202110_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  620BC6107255BF4C  electric_bike  2021-10-22 12:46:42  2021-10-22 12:49:50
# 1  4471C70731AB2E45  electric_bike  2021-10-21 09:12:37  2021-10-21 09:14:14
# 2  26CA69D43D15EE14  electric_bike  2021-10-16 16:28:39  2021-10-16 16:36:26
# 3  362947F0437E1514  electric_bike  2021-10-16 16:17:48  2021-10-16 16:19:03
# 4  BB731DE2F2EC51C5  electric_bike  2021-10-20 23:17:54  2021-10-20 23:26:10
#
#          start_station_name start_station_id end_station_name end_station_id  \
# 0  Kingsbury St & Kinzie St     KA1503000043              NaN            NaN
# 1                       NaN              NaN              NaN            NaN
# 2                       NaN              NaN              NaN            NaN
# 3                       NaN              NaN              NaN            NaN
# 4                       NaN              NaN              NaN            NaN
#
# ...

# %%
tripdata_202110_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631226 entries, 0 to 631225
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             631226 non-null  object
#  1   rideable_type       631226 non-null  object
#  2   started_at          631226 non-null  object
#  3   ended_at            631226 non-null  object
#  4   start_station_name  523016 non-null  object
#  5   start_station_id    523016 non-null  object
#  6   end_station_name    516392 non-null  object
#  7   end_station_id      516392 non-null  object
#  8   start_lat           631226 non-null  float64
#  9   start_lng           631226 non-null  float64
#  10  end_lat             630742 non-null  float64
#  11  end_lng             630742 non-null  float64
#  12  member_casual       631226 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 62.6+ MB

# %%
tripdata_202109_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  9DC7B962304CBFD8  electric_bike  2021-09-28 16:07:10  2021-09-28 16:09:54
# 1  F930E2C6872D6B32  electric_bike  2021-09-28 14:24:51  2021-09-28 14:40:05
# 2  6EF72137900BB910  electric_bike  2021-09-28 00:20:16  2021-09-28 00:23:57
# 3  78D1DE133B3DBF55  electric_bike  2021-09-28 14:51:17  2021-09-28 15:00:06
# 4  E03D4ACDCAEF6E00  electric_bike  2021-09-28 09:53:12  2021-09-28 10:03:44
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
tripdata_202109_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756147 entries, 0 to 756146
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             756147 non-null  object
#  1   rideable_type       756147 non-null  object
#  2   started_at          756147 non-null  object
#  3   ended_at            756147 non-null  object
#  4   start_station_name  663034 non-null  object
#  5   start_station_id    663036 non-null  object
#  6   end_station_name    656886 non-null  object
#  7   end_station_id      656886 non-null  object
#  8   start_lat           756147 non-null  float64
#  9   start_lng           756147 non-null  float64
#  10  end_lat             755552 non-null  float64
#  11  end_lng             755552 non-null  float64
#  12  member_casual       756147 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 75.0+ MB

# %%
tripdata_202108_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  99103BB87CC6C1BB  electric_bike  2021-08-10 17:15:49  2021-08-10 17:22:44
# 1  EAFCCCFB0A3FC5A1  electric_bike  2021-08-10 17:23:14  2021-08-10 17:39:24
# 2  9EF4F46C57AD234D  electric_bike  2021-08-21 02:34:23  2021-08-21 02:50:36
# 3  5834D3208BFAF1DA  electric_bike  2021-08-21 06:52:55  2021-08-21 07:08:13
# 4  CD825CB87ED1D096  electric_bike  2021-08-19 11:55:29  2021-08-19 12:04:11
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
tripdata_202108_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 804352 entries, 0 to 804351
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             804352 non-null  object
#  1   rideable_type       804352 non-null  object
#  2   started_at          804352 non-null  object
#  3   ended_at            804352 non-null  object
#  4   start_station_name  715894 non-null  object
#  5   start_station_id    715894 non-null  object
#  6   end_station_name    710237 non-null  object
#  7   end_station_id      710237 non-null  object
#  8   start_lat           804352 non-null  float64
#  9   start_lng           804352 non-null  float64
#  10  end_lat             803646 non-null  float64
#  11  end_lng             803646 non-null  float64
#  12  member_casual       804352 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 79.8+ MB

# %% [markdown]
# ## Start Preprocessing Data

# %% [markdown]
# ### concat 12 Dataframes

# %%
list_12_df = [tripdata_202108_df , tripdata_202109_df , tripdata_202110_df , tripdata_202111_df , tripdata_202112_df , tripdata_202201_df , tripdata_202202_df , tripdata_202203_df , tripdata_202204_df , tripdata_202205_df , tripdata_202206_df , tripdata_202207_df]
len(list_12_df)
# Out:
# 12

# %%
tripdata_last_12_months_df = pd.concat(list_12_df).reset_index(drop=True)
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        99103BB87CC6C1BB  electric_bike  2021-08-10 17:15:49
# 1        EAFCCCFB0A3FC5A1  electric_bike  2021-08-10 17:23:14
# 2        9EF4F46C57AD234D  electric_bike  2021-08-21 02:34:23
# 3        5834D3208BFAF1DA  electric_bike  2021-08-21 06:52:55
# 4        CD825CB87ED1D096  electric_bike  2021-08-19 11:55:29
# ...                   ...            ...                  ...
# 5901458  605787F70B3B9FD3  electric_bike  2022-07-09 08:32:15
# 5901459  F0EECBEE637DF028  electric_bike  2022-07-17 13:27:57
# 5901460  B8B091DC72DDAB9D  electric_bike  2022-07-17 14:51:37
# 5901461  B4D3FFCC1F3AF5EC  electric_bike  2022-07-28 13:41:50
# 5901462  AA9217C8DA3BAC0B  electric_bike  2022-07-29 13:05:20
#
#                     ended_at start_station_name start_station_id  \
# 0        2021-08-10 17:22:44                NaN              NaN
# 1        2021-08-10 17:39:24                NaN              NaN
# ...

# %%
tripdata_last_12_months_df['started_at'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### check if started_at and ended_at is datetime

# %%
tripdata_last_12_months_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901463 entries, 0 to 5901462
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 585.3+ MB

# %% [markdown]
# #### convert it to datetime

# %%
tripdata_last_12_months_df['started_at'] = pd.to_datetime(tripdata_last_12_months_df['started_at'])

# %%
tripdata_last_12_months_df['ended_at'] = pd.to_datetime(tripdata_last_12_months_df['ended_at'])

# %%
tripdata_last_12_months_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901463 entries, 0 to 5901462
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 585.3+ MB

# %%
tripdata_last_12_months_df['started_at'].dt.to_period('m')
# Out:
# 0          2021-08
# 1          2021-08
# 2          2021-08
# 3          2021-08
# 4          2021-08
#             ...
# 5901458    2022-07
# 5901459    2022-07
# 5901460    2022-07
# 5901461    2022-07
# 5901462    2022-07
# Name: started_at, Length: 5901463, dtype: period[M]

# %% [markdown]
# ### create month_year column

# %%
tripdata_last_12_months_df['month_year'] = tripdata_last_12_months_df['started_at'].dt.to_period('m')

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        99103BB87CC6C1BB  electric_bike 2021-08-10 17:15:49
# 1        EAFCCCFB0A3FC5A1  electric_bike 2021-08-10 17:23:14
# 2        9EF4F46C57AD234D  electric_bike 2021-08-21 02:34:23
# 3        5834D3208BFAF1DA  electric_bike 2021-08-21 06:52:55
# 4        CD825CB87ED1D096  electric_bike 2021-08-19 11:55:29
# ...                   ...            ...                 ...
# 5901458  605787F70B3B9FD3  electric_bike 2022-07-09 08:32:15
# 5901459  F0EECBEE637DF028  electric_bike 2022-07-17 13:27:57
# 5901460  B8B091DC72DDAB9D  electric_bike 2022-07-17 14:51:37
# 5901461  B4D3FFCC1F3AF5EC  electric_bike 2022-07-28 13:41:50
# 5901462  AA9217C8DA3BAC0B  electric_bike 2022-07-29 13:05:20
#
#                    ended_at start_station_name start_station_id  \
# 0       2021-08-10 17:22:44                NaN              NaN
# 1       2021-08-10 17:39:24                NaN              NaN
# ...

# %% [markdown]
# ### create columns duration_trip to calculate how much time customer spend on trip

# %%
tripdata_last_12_months_df['duration_trip'] = (tripdata_last_12_months_df['ended_at'] - tripdata_last_12_months_df['started_at'])
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        99103BB87CC6C1BB  electric_bike 2021-08-10 17:15:49
# 1        EAFCCCFB0A3FC5A1  electric_bike 2021-08-10 17:23:14
# 2        9EF4F46C57AD234D  electric_bike 2021-08-21 02:34:23
# 3        5834D3208BFAF1DA  electric_bike 2021-08-21 06:52:55
# 4        CD825CB87ED1D096  electric_bike 2021-08-19 11:55:29
# ...                   ...            ...                 ...
# 5901458  605787F70B3B9FD3  electric_bike 2022-07-09 08:32:15
# 5901459  F0EECBEE637DF028  electric_bike 2022-07-17 13:27:57
# 5901460  B8B091DC72DDAB9D  electric_bike 2022-07-17 14:51:37
# 5901461  B4D3FFCC1F3AF5EC  electric_bike 2022-07-28 13:41:50
# 5901462  AA9217C8DA3BAC0B  electric_bike 2022-07-29 13:05:20
#
#                    ended_at start_station_name start_station_id  \
# 0       2021-08-10 17:22:44                NaN              NaN
# 1       2021-08-10 17:39:24                NaN              NaN
# ...

# %% [markdown]
# ## Start cleaning table (5.9 M Row , 15col)

# %% [markdown]
# ### 1- about duration trip column we will drop all records when duration is 0 or less than 0 seconds because it is invalid data and we can't back to resource of data

# %%
dur_less_zero = tripdata_last_12_months_df[tripdata_last_12_months_df.duration_trip < pd.Timedelta(value=1)]
dur_less_zero
# Out:
#                   ride_id  rideable_type          started_at  \
# 35210    A2DBE0C0012129B1   classic_bike 2021-08-20 16:19:52
# 37252    6510818B0164570F   classic_bike 2021-08-07 17:38:36
# 48045    FCA3A0A1C527D8C6   classic_bike 2021-08-13 17:53:42
# 49901    FE2F91D8E78B0321   classic_bike 2021-08-28 15:16:45
# 70521    0291C81C6932E735  electric_bike 2021-08-20 16:20:35
# ...                   ...            ...                 ...
# 5771928  39C645A41FB8C1B9  electric_bike 2022-07-21 17:15:52
# 5823681  5DC10FD3E5CCF10E   classic_bike 2022-07-09 16:16:11
# 5864653  FE7998113CF7864B    docked_bike 2022-07-09 12:22:09
# 5873875  64491AACAD9C1585  electric_bike 2022-07-21 18:01:32
# 5886092  5DFC1956D804FD43  electric_bike 2022-07-15 02:54:43
#
#                    ended_at             start_station_name start_station_id  \
# 35210   2021-08-20 16:19:16  Sheffield Ave & Fullerton Ave     TA1306000016
# 37252   2021-08-07 17:38:36              Wells St & Elm St     KA1504000135
# ...

# %% [markdown]
# #### it is 636  record so we can drop it

# %%
tripdata_last_12_months_df.drop(labels=dur_less_zero.index,inplace=True)

# %%
tripdata_last_12_months_df['duration_trip'].min()
# Out:
# Timedelta('0 days 00:00:01')

# %%
tripdata_last_12_months_df
# 5901463 - 636 = 5900827
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        99103BB87CC6C1BB  electric_bike 2021-08-10 17:15:49
# 1        EAFCCCFB0A3FC5A1  electric_bike 2021-08-10 17:23:14
# 2        9EF4F46C57AD234D  electric_bike 2021-08-21 02:34:23
# 3        5834D3208BFAF1DA  electric_bike 2021-08-21 06:52:55
# 4        CD825CB87ED1D096  electric_bike 2021-08-19 11:55:29
# ...                   ...            ...                 ...
# 5901458  605787F70B3B9FD3  electric_bike 2022-07-09 08:32:15
# 5901459  F0EECBEE637DF028  electric_bike 2022-07-17 13:27:57
# 5901460  B8B091DC72DDAB9D  electric_bike 2022-07-17 14:51:37
# 5901461  B4D3FFCC1F3AF5EC  electric_bike 2022-07-28 13:41:50
# 5901462  AA9217C8DA3BAC0B  electric_bike 2022-07-29 13:05:20
#
#                    ended_at start_station_name start_station_id  \
# 0       2021-08-10 17:22:44                NaN              NaN
# 1       2021-08-10 17:39:24                NaN              NaN
# ...

# %% [markdown]
# ### 2- check duplicate value

# %%
tripdata_last_12_months_df.duplicated().sum()
# Out:
# 0

# %%
tripdata_last_12_months_df.ride_id.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### great there is no duplicates

# %%
tripdata_last_12_months_df.rideable_type.value_counts()
# Out:
# classic_bike     3055417
# electric_bike    2618693
# docked_bike       226717
# Name: rideable_type, dtype: int64

# %%
tripdata_last_12_months_df.describe()
# Out:
#           start_lat     start_lng       end_lat       end_lng  \
# count  5.900827e+06  5.900827e+06  5.895237e+06  5.895237e+06
# mean   4.190077e+01 -8.764742e+01  4.190102e+01 -8.764761e+01
# std    4.725615e-02  3.093902e-02  4.734808e-02  3.056543e-02
# min    4.164000e+01 -8.784000e+01  4.139000e+01 -8.897000e+01
# 25%    4.188103e+01 -8.766154e+01  4.188103e+01 -8.766241e+01
# 50%    4.189964e+01 -8.764335e+01  4.190000e+01 -8.764375e+01
# 75%    4.192957e+01 -8.762872e+01  4.192968e+01 -8.762911e+01
# max    4.563503e+01 -7.379648e+01  4.237000e+01 -8.750000e+01
#
#                    duration_trip
# count                    5900827
# mean   0 days 00:19:53.539191032
# std    0 days 02:27:59.567066531
# min              0 days 00:00:01
# 25%              0 days 00:06:10
# 50%              0 days 00:10:57
# 75%              0 days 00:19:49
# max             28 days 21:49:10

# %%
tripdata_last_12_months_df.duration_trip.sort_values(ascending=False).head(300)
# Out:
# 192711    28 days 21:49:10
# 1921053   28 days 06:25:01
# 4263940   25 days 04:17:48
# 4918839   24 days 21:00:38
# 2365323   24 days 07:17:43
#                 ...
# 2167815    7 days 23:16:29
# 4541018    7 days 23:13:05
# 4863616    7 days 23:11:24
# 4916223    7 days 22:50:33
# 5116642    7 days 22:37:31
# Name: duration_trip, Length: 300, dtype: timedelta64[ns]

# %%
tripdata_last_12_months_df[tripdata_last_12_months_df.duration_trip > pd.Timedelta(value=23 , unit='h')]
# Out:
#                   ride_id rideable_type          started_at  \
# 107      AACF749D1FD1F009  classic_bike 2021-08-19 00:50:54
# 2297     EBBF1DEC2EA52801  classic_bike 2021-08-22 23:06:30
# 6554     1051883B4EF4400F  classic_bike 2021-08-22 16:10:02
# 10870    73126E4C21CEA9AA  classic_bike 2021-08-11 20:56:59
# 10875    C43E2CF335AD44EF  classic_bike 2021-08-28 18:36:53
# ...                   ...           ...                 ...
# 5890829  8DFFC6C0D67FBCA3   docked_bike 2022-07-21 11:53:27
# 5892264  88DFB23D67E9AE10  classic_bike 2022-07-03 23:55:04
# 5892927  45B9C0C8957F4EB1   docked_bike 2022-07-22 15:27:12
# 5893112  B7CF81FCE91D8C03  classic_bike 2022-07-07 09:04:39
# 5897936  7A564ED64D234AFC   docked_bike 2022-07-02 11:45:19
#
#                    ended_at                   start_station_name  \
# 107     2021-08-20 01:50:48                Michigan Ave & Oak St
# 2297    2021-08-24 00:06:25               Indiana Ave & 103rd St
# ...

# %% [markdown]
# ### 3- outliers in duration trip

# %% [markdown]
# #### cal outlier

# %%
tripdata_last_12_months_df.duration_trip.dt.seconds.describe()
# Out:
# count    5.900827e+06
# mean     1.057530e+03
# std      2.016106e+03
# min      1.000000e+00
# 25%      3.700000e+02
# 50%      6.570000e+02
# 75%      1.189000e+03
# max      8.639700e+04
# Name: duration_trip, dtype: float64

# %%
duration_q1 = tripdata_last_12_months_df.duration_trip.dt.seconds.quantile(0.25)
duration_q1
# Out:
# 370.0

# %%
duration_q3 = tripdata_last_12_months_df.duration_trip.dt.seconds.quantile(0.75)
duration_q3
# Out:
# 1189.0

# %%
duration_iqr = duration_q3 - duration_q1
duration_iqr
# Out:
# 819.0

# %%
duration_min = duration_q1 - (1.5 * duration_iqr)
duration_min
# Out:
# -858.5

# %%
duration_max = duration_q3 + (1.5 * duration_iqr)
duration_max
# Out:
# 2417.5

# %%
tripdata_last_12_months_df[tripdata_last_12_months_df.duration_trip > pd.Timedelta(value=duration_max , unit='s')]
# Out:
#                   ride_id  rideable_type          started_at  \
# 37       2DDC27F6FA553D57  electric_bike 2021-08-10 17:20:16
# 43       5053F26F7840926C  electric_bike 2021-08-17 11:41:13
# 58       B0C8B69698AF5D2F  electric_bike 2021-08-10 18:37:18
# 59       904369F6B4544CA0  electric_bike 2021-08-15 11:52:52
# 71       AD8B410AA8B5F4FE  electric_bike 2021-08-12 09:28:31
# ...                   ...            ...                 ...
# 5901276  76BC33916161B7EE  electric_bike 2022-07-28 17:50:49
# 5901302  621F0DDC80CCAEE9  electric_bike 2022-07-10 18:01:51
# 5901355  61526ED68A599E9A  electric_bike 2022-07-09 11:02:32
# 5901367  81C0364652F2CC12  electric_bike 2022-07-22 21:54:04
# 5901435  4868465A22DFE52A  electric_bike 2022-07-29 14:15:32
#
#                    ended_at start_station_name start_station_id  \
# 37      2021-08-10 20:39:55                NaN              NaN
# 43      2021-08-17 14:00:04                NaN              NaN
# ...

# %% [markdown]
# #### there are 427 K record outlier it is a huge number and it is only 7% of total records we can't accept this number according to some research maximum percentage acceptable for outliers in data is 0.3% so we will remove highest 0.3 in our duration
#
# ##### 0.3% * 5900827 = 17702

# %%
outliers_duration = tripdata_last_12_months_df.duration_trip.sort_values(ascending=False).head(17702)
outliers_duration
# Out:
# 192711    28 days 21:49:10
# 1921053   28 days 06:25:01
# 4263940   25 days 04:17:48
# 4918839   24 days 21:00:38
# 2365323   24 days 07:17:43
#                 ...
# 2149465    0 days 03:28:41
# 5089865    0 days 03:28:40
# 2018109    0 days 03:28:40
# 3707154    0 days 03:28:40
# 4337113    0 days 03:28:39
# Name: duration_trip, Length: 17702, dtype: timedelta64[ns]

# %%
tripdata_last_12_months_df.drop(labels=outliers_duration.index , inplace=True)
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        99103BB87CC6C1BB  electric_bike 2021-08-10 17:15:49
# 1        EAFCCCFB0A3FC5A1  electric_bike 2021-08-10 17:23:14
# 2        9EF4F46C57AD234D  electric_bike 2021-08-21 02:34:23
# 3        5834D3208BFAF1DA  electric_bike 2021-08-21 06:52:55
# 4        CD825CB87ED1D096  electric_bike 2021-08-19 11:55:29
# ...                   ...            ...                 ...
# 5901458  605787F70B3B9FD3  electric_bike 2022-07-09 08:32:15
# 5901459  F0EECBEE637DF028  electric_bike 2022-07-17 13:27:57
# 5901460  B8B091DC72DDAB9D  electric_bike 2022-07-17 14:51:37
# 5901461  B4D3FFCC1F3AF5EC  electric_bike 2022-07-28 13:41:50
# 5901462  AA9217C8DA3BAC0B  electric_bike 2022-07-29 13:05:20
#
#                    ended_at start_station_name start_station_id  \
# 0       2021-08-10 17:22:44                NaN              NaN
# 1       2021-08-10 17:39:24                NaN              NaN
# ...

# %%
tripdata_last_12_months_df.duration_trip.max()
# Out:
# Timedelta('0 days 03:28:39')

# %% [markdown]
# #### but it is better to back to data source to ask him about this outlier  , It is possible that there is a bug and because of it the counting did not stop or the customer delivered his bike but forgot to press the button and then the customer called to remove the bill from him. If there are problems like these, it is better to remove it
#
# #### But if it's not like that and real things like someone traveled by bike or something like that it's better not to remove it

# %%
tripdata_last_12_months_df.head()
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  99103BB87CC6C1BB  electric_bike 2021-08-10 17:15:49 2021-08-10 17:22:44
# 1  EAFCCCFB0A3FC5A1  electric_bike 2021-08-10 17:23:14 2021-08-10 17:39:24
# 2  9EF4F46C57AD234D  electric_bike 2021-08-21 02:34:23 2021-08-21 02:50:36
# 3  5834D3208BFAF1DA  electric_bike 2021-08-21 06:52:55 2021-08-21 07:08:13
# 4  CD825CB87ED1D096  electric_bike 2021-08-19 11:55:29 2021-08-19 12:04:11
#
#   start_station_name start_station_id end_station_name end_station_id  \
# 0                NaN              NaN              NaN            NaN
# 1                NaN              NaN              NaN            NaN
# 2                NaN              NaN              NaN            NaN
# 3                NaN              NaN              NaN            NaN
# 4                NaN              NaN              NaN            NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual month_year  \
# ...

# %%
tripdata_last_12_months_df.started_at.max()
# Out:
# Timestamp('2022-07-31 23:59:58')

# %%
tripdata_last_12_months_df.started_at.min()
# Out:
# Timestamp('2021-08-01 00:00:04')

# %% [markdown]
# ### 4- handling with Nan Values

# %%
tripdata_last_12_months_df.member_casual.value_counts()
# Out:
# member    3375807
# casual    2507318
# Name: member_casual, dtype: int64

# %%
tripdata_last_12_months_df.isna().sum()
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    859909
# start_station_id      859907
# end_station_name      912768
# end_station_id        912768
# start_lat                  0
# start_lng                  0
# end_lat                  731
# end_lng                  731
# member_casual              0
# month_year                 0
# duration_trip              0
# dtype: int64

# %%
tripdata_last_12_months_df[tripdata_last_12_months_df.end_lat.isna()]
# Out:
#                   ride_id rideable_type          started_at  \
# 5862     F173E0425B5226F4  classic_bike 2021-08-12 17:45:55
# 14320    7182D30D6A8188A7  classic_bike 2021-08-14 13:41:48
# 100009   C20D9AF151647870  classic_bike 2021-08-31 18:30:43
# 100745   06137057C0161533  classic_bike 2021-08-20 18:08:04
# 102658   424AF0C58666E4E7  classic_bike 2021-08-14 11:03:21
# ...                   ...           ...                 ...
# 5777800  3E0166C3AC3FDB67   docked_bike 2022-07-08 10:53:19
# 5779226  D99AD8A006DD7B40   docked_bike 2022-07-25 13:20:08
# 5779265  0BC879C9102D7687   docked_bike 2022-07-08 16:55:47
# 5873262  06D75D640057B687   docked_bike 2022-07-16 15:07:57
# 5883292  DC94A386EB73E5A1   docked_bike 2022-07-03 10:51:02
#
#                    ended_at              start_station_name start_station_id  \
# 5862    2021-08-12 21:01:39           Michigan Ave & Oak St            13042
# 14320   2021-08-14 15:28:37           Michigan Ave & Oak St            13042
# ...

# %%
na_end_lat_lng = tripdata_last_12_months_df[(tripdata_last_12_months_df.end_lat.isna()) & (tripdata_last_12_months_df.end_station_name.isna())]
na_end_lat_lng
# Out:
#                   ride_id rideable_type          started_at  \
# 5862     F173E0425B5226F4  classic_bike 2021-08-12 17:45:55
# 14320    7182D30D6A8188A7  classic_bike 2021-08-14 13:41:48
# 100009   C20D9AF151647870  classic_bike 2021-08-31 18:30:43
# 100745   06137057C0161533  classic_bike 2021-08-20 18:08:04
# 102658   424AF0C58666E4E7  classic_bike 2021-08-14 11:03:21
# ...                   ...           ...                 ...
# 5777800  3E0166C3AC3FDB67   docked_bike 2022-07-08 10:53:19
# 5779226  D99AD8A006DD7B40   docked_bike 2022-07-25 13:20:08
# 5779265  0BC879C9102D7687   docked_bike 2022-07-08 16:55:47
# 5873262  06D75D640057B687   docked_bike 2022-07-16 15:07:57
# 5883292  DC94A386EB73E5A1   docked_bike 2022-07-03 10:51:02
#
#                    ended_at              start_station_name start_station_id  \
# 5862    2021-08-12 21:01:39           Michigan Ave & Oak St            13042
# 14320   2021-08-14 15:28:37           Michigan Ave & Oak St            13042
# ...

# %% [markdown]
# #### all end lat or lng null values have null values too in end station and they are only 731 record so it is better to remove them

# %%
tripdata_last_12_months_df.drop(labels=na_end_lat_lng.index , inplace=True)
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        99103BB87CC6C1BB  electric_bike 2021-08-10 17:15:49
# 1        EAFCCCFB0A3FC5A1  electric_bike 2021-08-10 17:23:14
# 2        9EF4F46C57AD234D  electric_bike 2021-08-21 02:34:23
# 3        5834D3208BFAF1DA  electric_bike 2021-08-21 06:52:55
# 4        CD825CB87ED1D096  electric_bike 2021-08-19 11:55:29
# ...                   ...            ...                 ...
# 5901458  605787F70B3B9FD3  electric_bike 2022-07-09 08:32:15
# 5901459  F0EECBEE637DF028  electric_bike 2022-07-17 13:27:57
# 5901460  B8B091DC72DDAB9D  electric_bike 2022-07-17 14:51:37
# 5901461  B4D3FFCC1F3AF5EC  electric_bike 2022-07-28 13:41:50
# 5901462  AA9217C8DA3BAC0B  electric_bike 2022-07-29 13:05:20
#
#                    ended_at start_station_name start_station_id  \
# 0       2021-08-10 17:22:44                NaN              NaN
# 1       2021-08-10 17:39:24                NaN              NaN
# ...

# %% [markdown]
# ### we will not handle with station Nan values because our goal is mainly focus of type of customer

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        99103BB87CC6C1BB  electric_bike 2021-08-10 17:15:49
# 1        EAFCCCFB0A3FC5A1  electric_bike 2021-08-10 17:23:14
# 2        9EF4F46C57AD234D  electric_bike 2021-08-21 02:34:23
# 3        5834D3208BFAF1DA  electric_bike 2021-08-21 06:52:55
# 4        CD825CB87ED1D096  electric_bike 2021-08-19 11:55:29
# ...                   ...            ...                 ...
# 5901458  605787F70B3B9FD3  electric_bike 2022-07-09 08:32:15
# 5901459  F0EECBEE637DF028  electric_bike 2022-07-17 13:27:57
# 5901460  B8B091DC72DDAB9D  electric_bike 2022-07-17 14:51:37
# 5901461  B4D3FFCC1F3AF5EC  electric_bike 2022-07-28 13:41:50
# 5901462  AA9217C8DA3BAC0B  electric_bike 2022-07-29 13:05:20
#
#                    ended_at start_station_name start_station_id  \
# 0       2021-08-10 17:22:44                NaN              NaN
# 1       2021-08-10 17:39:24                NaN              NaN
# ...

# %% [markdown]
# #### Sort dataframe by started at

# %%
tripdata_last_12_months_df.sort_values(by=['started_at' , 'ended_at'] , inplace=True)
tripdata_last_12_months_df.reset_index(drop=True,inplace=True)
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %% [markdown]
# ### add day of week and hour of day columns

# %%
tripdata_last_12_months_df['day_of_week'] = tripdata_last_12_months_df['started_at'].dt.dayofweek
tripdata_last_12_months_df
#0 = monday , 6 = sunday
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
tripdata_last_12_months_df['hour_of_day'] = tripdata_last_12_months_df['started_at'].dt.hour
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
tripdata_last_12_months_df.member_casual.value_counts()
# Out:
# member    3375638
# casual    2506756
# Name: member_casual, dtype: int64

# %%
tripdata_last_12_months_df.start_station_name.value_counts().head(500)
# Out:
# Streeter Dr & Grand Ave               79915
# DuSable Lake Shore Dr & North Blvd    45214
# Michigan Ave & Oak St                 42984
# DuSable Lake Shore Dr & Monroe St     42805
# Wells St & Concord Ln                 42361
#                                       ...
# Long & Irving Park                      889
# Prairie Ave & 43rd St                   879
# California Ave & 23rd Pl                874
# Narragansett & Wrightwood               863
# Dorchester Ave & 63rd St                863
# Name: start_station_name, Length: 500, dtype: int64

# %% [markdown]
# ## Analysis and EDA
# ### no we finished Preprocessing 90% , we can start now in analysis and we find anything want to clean or change we will do it in analysis step

# %% [markdown]
# ### Questions (General)
#
# - 1- what is mean of duration of trip ?
# - 2- mean of duration for each day
# - 3- mean of duration for each hour
# - 4- mean of duration monthly for last 12 months
# - 5- Arrange the days in terms of the most requested bikes in general
# - 6- Arrange the days in terms of the most requested bikes for each month
# - 7- Most and least demand hours in general
# - 8- Most and least demand hours for each day of the week (deleted)
# - 9- performance of number of trips for each month in last 12 month
# - 10- The most and least stations from which trips start
# - 11- The percentage of the types of bikes at each station
# - 12- most and least five hours are start a new trip at Clark St & Wrightwood Ave station
#
# ### Questions for member and casual
# - 13- ratio of member and casual
# - 14- ratio change of member and casual monthly for last 12 month
# - 15- is member and casual choose the same type of bike
# - 16- Arrange the days in terms of the most requested bikes for member and casual
# - 17- Most and least demand hours for member and casual
# - 18- mean of duration of trip for member and casual
# - 19- ratio of start a trip from member and casual for Clark St & Wrightwood Ave station station

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %% [markdown]
# ### Q1 : what is mean of duration of trip ?

# %%
tripdata_last_12_months_df.duration_trip.mean()
# Out:
# Timedelta('0 days 00:16:28.209684016')

# %% [markdown]
# ### A1 : Mean of duration trip is 16 Minutes and 28 Seconds

# %% [markdown]
# ### Q2 : mean of duration for each day ?

# %%
mean_duration_per_day = tripdata_last_12_months_df.groupby('day_of_week')['duration_trip'].mean().dt.seconds
mean_duration_per_day
# Out:
# day_of_week
# 0     966
# 1     854
# 2     856
# 3     882
# 4     936
# 5    1166
# 6    1195
# Name: duration_trip, dtype: int64

# %%
mean_duration_per_day.sort_values()
# Out:
# day_of_week
# 1     854
# 2     856
# 3     882
# 4     936
# 0     966
# 5    1166
# 6    1195
# Name: duration_trip, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(mean_duration_per_day.index , mean_duration_per_day.values)
plt.title('mean duration per day')
plt.ylabel("mean duration in seconds")
plt.xlabel("day of week (0 = monday)")
# Out:
# Text(0.5, 0, 'day of week (0 = monday)')

# %% [markdown]
# ### A2 : it is mean of duration per day of week , as we can see highest day is 6 (sunday) and lowest is 1 (tuesday)
# ### mean of duration increasing between 4 - 6 , and dereasing between 1-3

# %% [markdown]
# ### Q3 : mean of duration for each hour

# %%
mean_duration_per_hour = tripdata_last_12_months_df.groupby('hour_of_day')['duration_trip'].mean().dt.seconds
mean_duration_per_hour
# Out:
# hour_of_day
# 0      924
# 1      925
# 2      940
# 3      925
# 4      849
# 5      712
# 6      726
# 7      746
# 8      771
# 9      909
# 10    1070
# 11    1118
# 12    1092
# 13    1122
# 14    1140
# 15    1089
# 16    1024
# 17     981
# 18     968
# 19     958
# 20     947
# 21     925
# 22     918
# 23     926
# Name: duration_trip, dtype: int64

# %%
mean_duration_per_hour.sort_values()
# Out:
# hour_of_day
# 5      712
# 6      726
# 7      746
# 8      771
# 4      849
# 9      909
# 22     918
# 0      924
# 1      925
# 21     925
# 3      925
# 23     926
# 2      940
# 20     947
# 19     958
# 18     968
# 17     981
# 16    1024
# 10    1070
# 15    1089
# 12    1092
# 11    1118
# 13    1122
# 14    1140
# Name: duration_trip, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(mean_duration_per_hour.index , mean_duration_per_hour.values)
plt.title('mean duration for hours')
plt.ylabel("mean duration in seconds")
plt.xlabel("hours of day (start from zero)")
# Out:
# Text(0.5, 0, 'hours of day (start from zero)')

# %% [markdown]
# ### A3 : there is Series of hours start from zero as we can see highest duration between 10 to 15 , so we can provide more bikes in this time
# ### and lowest duration between 5-9

# %% [markdown]
# ### Q4 : mean of duration monthly for last 12 months

# %%
mean_duration_for_months = tripdata_last_12_months_df.groupby('month_year')['duration_trip'].mean().dt.seconds
mean_duration_for_months
# Out:
# month_year
# 2021-08    1141
# 2021-09    1077
# 2021-10     931
# 2021-11     756
# 2021-12     737
# 2022-01     679
# 2022-02     709
# 2022-03     880
# 2022-04     873
# 2022-05    1052
# 2022-06    1042
# 2022-07    1044
# Freq: M, Name: duration_trip, dtype: int64

# %%
mean_duration_for_months.sort_values()
# Out:
# month_year
# 2022-01     679
# 2022-02     709
# 2021-12     737
# 2021-11     756
# 2022-04     873
# 2022-03     880
# 2021-10     931
# 2022-06    1042
# 2022-07    1044
# 2022-05    1052
# 2021-09    1077
# 2021-08    1141
# Freq: M, Name: duration_trip, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(mean_duration_for_months.index.astype('str') , mean_duration_for_months.values)
plt.title('mean duration Monthly for last 12 month')
plt.ylabel("mean duration in seconds")
plt.xlabel("Month")
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# ### A4 : we was facing an issues between 11-2021 and 02-2022 because mean of duration was very low , but now we back to the top

# %% [markdown]
# ### Q5 : Arrange the days in terms of the most requested bikes in general

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
trips_count_per_day = tripdata_last_12_months_df.groupby('day_of_week')['day_of_week'].count()
trips_count_per_day
# Out:
# day_of_week
# 0    769678
# 1    795269
# 2    802616
# 3    836594
# 4    811885
# 5    976955
# 6    889397
# Name: day_of_week, dtype: int64

# %%
# or using value counts
tripdata_last_12_months_df['day_of_week'].value_counts()
# Out:
# 5    976955
# 6    889397
# 3    836594
# 4    811885
# 2    802616
# 1    795269
# 0    769678
# Name: day_of_week, dtype: int64

# %%
trips_count_per_day.sort_values()
# Out:
# day_of_week
# 0    769678
# 1    795269
# 2    802616
# 4    811885
# 3    836594
# 6    889397
# 5    976955
# Name: day_of_week, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(trips_count_per_day.index , trips_count_per_day.values)
plt.title('Trips count per day')
plt.ylabel("Total Trips")
plt.xlabel("Day (0 = monday)")
plt.ylim(0,(trips_count_per_day.values.max() + 100000))
# Out:
# (0.0, 1076955.0)

# %% [markdown]
# ### A5 : as we can see demand increase in sunday and saturday by (10-20)%

# %% [markdown]
# ### Q6 : Arrange the days in terms of the most requested bikes for last 3 months

# %%
trips_count_per_day_monthly = tripdata_last_12_months_df.groupby(['month_year' , 'day_of_week'])['day_of_week'].count()[['2022-07' , '2022-06' , '2022-05']]
trips_count_per_day_monthly
# Out:
# month_year  day_of_week
# 2022-07     0               93482
#             1               98712
#             2              102268
#             3              108714
#             4              117797
#             5              163419
#             6              136458
# 2022-06     0               83496
#             1               93479
#             2              116847
#             3              131040
#             4              112829
#             5              114338
#             6              114415
# 2022-05     0              109150
#             1               94380
#             2               68984
#             3               84827
#             4               74334
#             5               97447
#             6              103604
# Name: day_of_week, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(trips_count_per_day_monthly['2022-05'].index , trips_count_per_day_monthly['2022-05'].values)
plt.plot(trips_count_per_day_monthly['2022-06'].index , trips_count_per_day_monthly['2022-06'].values)
plt.plot(trips_count_per_day_monthly['2022-07'].index , trips_count_per_day_monthly['2022-07'].values)
plt.title('Trips count per day last 3 months')
plt.ylabel("Total Trips")
plt.xlabel("Day (0 = monday)")
# Out:
# Text(0.5, 0, 'Day (0 = monday)')

# %% [markdown]
# ### Q7 : Most and least demand hours in general

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
total_trips_for_each_hour = tripdata_last_12_months_df.groupby('hour_of_day')['ride_id'].count()
total_trips_for_each_hour
# Out:
# hour_of_day
# 0      86927
# 1      57148
# 2      35102
# 3      20646
# 4      18372
# 5      47171
# 6     119024
# 7     225105
# 8     273203
# 9     225183
# 10    244224
# 11    303357
# 12    352526
# 13    358505
# 14    362478
# 15    411067
# 16    497858
# 17    585801
# 18    501235
# 19    370601
# 20    264929
# 21    214301
# 22    179561
# 23    128070
# Name: ride_id, dtype: int64

# %%
total_trips_for_each_hour.sort_values()
# Out:
# hour_of_day
# 4      18372
# 3      20646
# 2      35102
# 5      47171
# 1      57148
# 0      86927
# 6     119024
# 23    128070
# 22    179561
# 21    214301
# 7     225105
# 9     225183
# 10    244224
# 20    264929
# 8     273203
# 11    303357
# 12    352526
# 13    358505
# 14    362478
# 19    370601
# 15    411067
# 16    497858
# 18    501235
# 17    585801
# Name: ride_id, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(total_trips_for_each_hour.index , total_trips_for_each_hour.values)
plt.title('Trips count per hour')
plt.ylabel("Total Trips")
plt.xlabel("hour")
plt.ylim(0,(total_trips_for_each_hour.values.max()))
# Out:
# (0.0, 585801.0)

# %% [markdown]
# ### what if we filtered day and choose only business days ?

# %%
total_trips_for_each_hour_business_days = tripdata_last_12_months_df[tripdata_last_12_months_df.day_of_week >5].groupby('hour_of_day')['ride_id'].count()
total_trips_for_each_hour_business_days
# Out:
# hour_of_day
# 0     27394
# 1     19011
# 2     12793
# 3      7037
# 4      4354
# 5      4289
# 6      7369
# 7     11792
# 8     19940
# 9     33806
# 10    50255
# 11    63410
# 12    69670
# 13    71845
# 14    73102
# 15    76286
# 16    73243
# 17    66836
# 18    57778
# 19    44988
# 20    32355
# 21    25948
# 22    21670
# 23    14226
# Name: ride_id, dtype: int64

# %%
total_trips_for_each_hour_business_days.sort_values()
# Out:
# hour_of_day
# 5      4289
# 4      4354
# 3      7037
# 6      7369
# 7     11792
# 2     12793
# 23    14226
# 1     19011
# 8     19940
# 22    21670
# 21    25948
# 0     27394
# 20    32355
# 9     33806
# 19    44988
# 10    50255
# 18    57778
# 11    63410
# 17    66836
# 12    69670
# 13    71845
# 14    73102
# 16    73243
# 15    76286
# Name: ride_id, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(total_trips_for_each_hour_business_days.index , total_trips_for_each_hour_business_days.values)
plt.title('Trips count per hour')
plt.ylabel("Total Trips")
plt.xlabel("hour")
plt.ylim(0,(total_trips_for_each_hour_business_days.values.max()))
# Out:
# (0.0, 76286.0)

# %% [markdown]
# ### A7 : we have 3 levels of demand (low - medium - high)
# ### 0-6 LOW
# ### 6-13 & 19-23 Medium
# ### 13-19 High

# %% [markdown]
# ### Q8 ; deleted

# %% [markdown]
# ### Q9 : performance of number of trips for each month in last 12 month

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
number_of_trip_monthly = tripdata_last_12_months_df.groupby('month_year')['ride_id'].count()
number_of_trip_monthly
# Out:
# month_year
# 2021-08    801205
# 2021-09    753423
# 2021-10    629207
# 2021-11    359195
# 2021-12    247065
# 2022-01    103436
# 2022-02    115332
# 2022-03    283221
# 2022-04    370290
# 2022-05    632726
# 2022-06    766444
# 2022-07    820850
# Freq: M, Name: ride_id, dtype: int64

# %%
# or using value counts
tripdata_last_12_months_df['month_year'].value_counts()
# Out:
# 2022-07    820850
# 2021-08    801205
# 2022-06    766444
# 2021-09    753423
# 2022-05    632726
# 2021-10    629207
# 2022-04    370290
# 2021-11    359195
# 2022-03    283221
# 2021-12    247065
# 2022-02    115332
# 2022-01    103436
# Freq: M, Name: month_year, dtype: int64

# %%
number_of_trip_monthly.sort_values()
# Out:
# month_year
# 2022-01    103436
# 2022-02    115332
# 2021-12    247065
# 2022-03    283221
# 2021-11    359195
# 2022-04    370290
# 2021-10    629207
# 2022-05    632726
# 2021-09    753423
# 2022-06    766444
# 2021-08    801205
# 2022-07    820850
# Freq: M, Name: ride_id, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(number_of_trip_monthly.index.astype('str') , number_of_trip_monthly.values)
plt.title('Trips count monthly')
plt.ylabel("Total Trips")
plt.xlabel("month")
plt.ylim(0,(number_of_trip_monthly.values.max()))
# Out:
# (0.0, 820850.0)

# %% [markdown]
# ### A9 : like mean of duration monthly  , we was facing issue between 12-2021 ad 03-2022  , we was in down trend  start from 08-2021 until we reah bottom then we start a up trend to reach highet number of trips in last 12 month in 07-2022

# %% [markdown]
# ### Q10 : The most and least stations from which trips start

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
start_stations_valuecounts = tripdata_last_12_months_df['start_station_name'].value_counts()
start_stations_valuecounts
# Out:
# Streeter Dr & Grand Ave                79915
# DuSable Lake Shore Dr & North Blvd     45214
# Michigan Ave & Oak St                  42984
# DuSable Lake Shore Dr & Monroe St      42805
# Wells St & Concord Ln                  42361
#                                        ...
# Lamon Ave & Archer Ave                     1
# Legler Regional Library                    1
# Hamilton Park                              1
# Stony Island & 95th St                     1
# Public Rack - 53rd St & Indiana Ave        1
# Name: start_station_name, Length: 1380, dtype: int64

# %%
start_stations_valuecounts.nlargest(20)
# Out:
# Streeter Dr & Grand Ave               79915
# DuSable Lake Shore Dr & North Blvd    45214
# Michigan Ave & Oak St                 42984
# DuSable Lake Shore Dr & Monroe St     42805
# Wells St & Concord Ln                 42361
# Millennium Park                       38334
# Clark St & Elm St                     38329
# Wells St & Elm St                     36123
# Theater on the Lake                   36052
# Kingsbury St & Kinzie St              35860
# Clark St & Armitage Ave               31992
# Broadway & Barry Ave                  31213
# Wabash Ave & Grand Ave                30923
# Clark St & Lincoln Ave                30774
# Wells St & Huron St                   29511
# Dearborn St & Erie St                 29404
# Wilton Ave & Belmont Ave              29048
# St. Clair St & Erie St                28133
# Indiana Ave & Roosevelt Rd            28124
# Clinton St & Madison St               27370
# Name: start_station_name, dtype: int64

# %%
start_stations_valuecounts.nsmallest(20)
# Out:
# Public Rack - Ewing Ave & 107th St              1
# Mackinaw Ave & 85th St                          1
# Public Rack - Western Ave & 98th St             1
# Vincennes Ave & 95th Pl                         1
# Public Rack - Union Ave & 111th St              1
# Whipple St & Irving Park Rd                     1
# Ashland Ave & 73rd St                           1
# Senka "Edward Duke" Park                        1
# Oketo Ave & Belmont Ave                         1
# Public Rack - Peterson Ave & Bernard Ave        1
# Pawel Bialowas - Test- PBSC charging station    1
# Public Rack - Champlain Ave & 65th St           1
# Back of the Yards Park                          1
# Panama Ave & Forest Preserve Ave                1
# Public Rack - Western Ave & 107th Pl            1
# Marquette Ave & 83rd St                         1
# May St & 78th St                                1
# Loomis Blvd & 83rd St                           1
# Public Rack - Kingston Ave & 75th St            1
# ...

# %%
start_stations_valuecounts[start_stations_valuecounts.values == 1]
# Out:
# Public Rack - Ewing Ave & 107th St     1
# Mackinaw Ave & 85th St                 1
# Public Rack - Western Ave & 98th St    1
# Vincennes Ave & 95th Pl                1
# Public Rack - Union Ave & 111th St     1
#                                       ..
# Lamon Ave & Archer Ave                 1
# Legler Regional Library                1
# Hamilton Park                          1
# Stony Island & 95th St                 1
# Public Rack - 53rd St & Indiana Ave    1
# Name: start_station_name, Length: 77, dtype: int64

# %% [markdown]
# ### there are 77 station only started 1 trip in last 12 month

# %% [markdown]
# ### Q11 : The percentage of the types of bikes

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
bike_types = tripdata_last_12_months_df['rideable_type'].value_counts()
bike_types
# Out:
# classic_bike     3045358
# electric_bike    2616851
# docked_bike       220185
# Name: rideable_type, dtype: int64

# %%
bike_types_percentage = ((bike_types.values / bike_types.values.sum()) * 100).round(2)
bike_types_percentage
# Out:
# array([51.77, 44.49,  3.74])

# %%
plt.figure(figsize=(20,10))
plt.bar(bike_types.index , bike_types_percentage)
plt.title('percentage of bike')
plt.xlabel("bike type")
# Out:
# Text(0.5, 0, 'bike type')

# %% [markdown]
# ### A11 :
# ### 51.77% :classic
# ### 44.49% :electric
# ### 3.74% :docked

# %% [markdown]
# ### Q12: most and least five hours are start a new trip at Clark St & Wrightwood Ave station

# %%
Clark_station_trips = tripdata_last_12_months_df[tripdata_last_12_months_df.start_station_name == "Clark St & Wrightwood Ave"]
Clark_station_trips
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 461      91D4D9DE77637F94   classic_bike 2021-08-01 00:24:27
# 590      F1206BA8AF4B6231   classic_bike 2021-08-01 00:32:44
# 604      DCE022752A3A3856   classic_bike 2021-08-01 00:33:50
# 657      A68FCF12216BA499   classic_bike 2021-08-01 00:37:11
# ...                   ...            ...                 ...
# 5881285  C359BC43706DAFE6  electric_bike 2022-07-31 22:19:59
# 5881497  33F8FA27BFC798B6   classic_bike 2022-07-31 22:32:21
# 5881602  2F8B8EA273315CEE   classic_bike 2022-07-31 22:39:29
# 5881960  4CCA1E258D833095  electric_bike 2022-07-31 23:02:27
# 5882306  45DD534DC5476878  electric_bike 2022-07-31 23:43:03
#
#                    ended_at         start_station_name start_station_id  \
# 0       2021-08-01 00:13:28  Clark St & Wrightwood Ave     TA1305000014
# 461     2021-08-01 00:32:36  Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
Clark_station_trips_hours = Clark_station_trips['hour_of_day'].value_counts()
Clark_station_trips_hours
# Out:
# 18    2814
# 17    2525
# 16    1860
# 19    1798
# 12    1618
# 15    1580
# 13    1548
# 14    1429
# 11    1390
# 10    1245
# 7     1228
# 20    1178
# 8     1150
# 9     1096
# 21     942
# 22     860
# 6      681
# 23     544
# 0      392
# 5      309
# 1      306
# 2      169
# 3      130
# 4       66
# Name: hour_of_day, dtype: int64

# %%
Clark_station_trips_hours.sort_values()
# Out:
# 4       66
# 3      130
# 2      169
# 1      306
# 5      309
# 0      392
# 23     544
# 6      681
# 22     860
# 21     942
# 9     1096
# 8     1150
# 20    1178
# 7     1228
# 10    1245
# 11    1390
# 14    1429
# 13    1548
# 15    1580
# 12    1618
# 19    1798
# 16    1860
# 17    2525
# 18    2814
# Name: hour_of_day, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.bar(Clark_station_trips_hours.index , Clark_station_trips_hours.values)
# plt.title('trips for each hour')
# plt.ylabel('trips count')
# plt.xlabel("hours")
# Out:
# <BarContainer object of 24 artists>

# %% [markdown]
# ### ِObservation from all 12 question above before start on main goal (from questions 1 to 12)
#
# * PART 1
#  * Mean of Duration increasing in Saturday and Sunday (Q2)
#  * Also Total number of trips increasing In Saturday and sunday (Q5)
#  * saturday and sunday is not business days in USA so we can conclude that a lot of people using bikes more in weekends And we can take advantage of that
#
# * PART 2
#  * Highest time people start trips between 13-19 in all days but in business days 12-17 was highest time and the difference between these five hours and the reset of day inceased  (Q7)
#  * We can conclude that the time when employees leave work is the most demanding time on working days, and we can benefit from that
#
# * PART 3
#  * total number of trips and mean of duration was in lowest level between these months from 12-2021 to 03-2022 so we was facing a problem in this time

# %% [markdown]
# ### recommendations (from questions 1 to 12)
#
# * (From Part 1) If we want to run an advertising campaign to increase users, we can target people who want to go out on weekend days and also add a reservation feature to them if they want to make sure that they have a bike before going out and offers for couples
#
# * (From Part 2) Increasing the number of stations close to workplaces and increasing the number of rentable bikes available in these stations, especially at the time of employees’ departure. It is possible to make special offers for employees or go to companies and make contracts with them if they want to provide employees with special packages for those who work for them
#
# * (From Part 1 and 2) To increase efficiency in the future, it is possible to differentiate between stations that are more directed to employees or working days and other stations that are directed to people who start trips on weekends. After determining the types of stations, we will transfer the largest number of bikes to stations designated for employees on working days, either Weekends we will transfer bikes to other stations directed on holidaysTo increase efficiency in the future, it is possible to differentiate between stations that are more directed to employees or working days and other stations that are directed to people who start trips on weekends. After determining the types of stations, we will transfer the largest number of bikes to stations designated for employees on working days, either Weekends we will transfer bikes to other stations directed on holidays

# %% [markdown]
# ### Q13: ratio of member and casual

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
member_casual_value_counts = tripdata_last_12_months_df['member_casual'].value_counts()
member_casual_value_counts
# Out:
# member    3375638
# casual    2506756
# Name: member_casual, dtype: int64

# %%
sum(member_casual_value_counts)
# Out:
# 5882394

# %%
member_casual_value_counts_perncentage = (member_casual_value_counts.values / sum(member_casual_value_counts)) * 100
member_casual_value_counts_perncentage
# Out:
# array([57.38544545, 42.61455455])

# %%
plt.figure(figsize=(20,10))
plt.bar(member_casual_value_counts.index , member_casual_value_counts_perncentage)
plt.title('percentage of member and casual')
# Out:
# Text(0.5, 1.0, 'percentage of member and casual')

# %% [markdown]
# ### Q14 : ratio change of member and casual monthly for last 12 month

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
monthly_member_vs_casual = tripdata_last_12_months_df.groupby(['month_year' , 'member_casual'])['member_casual'].count()
monthly_member_vs_casual
# Out:
# month_year  member_casual
# 2021-08     casual           410012
#             member           391193
# 2021-09     casual           361708
#             member           391715
# 2021-10     casual           255636
#             member           373571
# 2021-11     casual           106435
#             member           252760
# 2021-12     casual            69415
#             member           177650
# 2022-01     casual            18392
#             member            85044
# 2022-02     casual            21267
#             member            94065
# 2022-03     casual            89274
#             member           193947
# 2022-04     casual           125642
#             member           244648
# 2022-05     casual           278545
#             member           354181
# 2022-06     casual           366672
#             member           399772
# 2022-07     casual           403758
#             member           417092
# Name: member_casual, dtype: int64

# %%
monthly_member_vs_casual.values
# Out:
# array([410012, 391193, 361708, 391715, 255636, 373571, 106435, 252760,
#         69415, 177650,  18392,  85044,  21267,  94065,  89274, 193947,
#        125642, 244648, 278545, 354181, 366672, 399772, 403758, 417092],
#       dtype=int64)

# %%
monthly_member_vs_casual_df = pd.DataFrame(monthly_member_vs_casual)
monthly_member_vs_casual_df
# Out:
#                           member_casual
# month_year member_casual
# 2021-08    casual                410012
#            member                391193
# 2021-09    casual                361708
#            member                391715
# 2021-10    casual                255636
#            member                373571
# 2021-11    casual                106435
#            member                252760
# 2021-12    casual                 69415
#            member                177650
# 2022-01    casual                 18392
#            member                 85044
# 2022-02    casual                 21267
#            member                 94065
# 2022-03    casual                 89274
#            member                193947
# 2022-04    casual                125642
#            member                244648
# 2022-05    casual                278545
#            member                354181
# 2022-06    casual                366672
#            member                399772
# ...

# %%
monthly_total_trips = tripdata_last_12_months_df['month_year'].value_counts()
monthly_total_trips_2 = pd.concat([monthly_total_trips,monthly_total_trips]).sort_index()
monthly_total_trips_2
# Out:
# 2021-08    801205
# 2021-08    801205
# 2021-09    753423
# 2021-09    753423
# 2021-10    629207
# 2021-10    629207
# 2021-11    359195
# 2021-11    359195
# 2021-12    247065
# 2021-12    247065
# 2022-01    103436
# 2022-01    103436
# 2022-02    115332
# 2022-02    115332
# 2022-03    283221
# 2022-03    283221
# 2022-04    370290
# 2022-04    370290
# 2022-05    632726
# 2022-05    632726
# 2022-06    766444
# 2022-06    766444
# 2022-07    820850
# 2022-07    820850
# Freq: M, Name: month_year, dtype: int64

# %%
monthly_member_vs_casual_df['member_casual'].values
# Out:
# array([410012, 391193, 361708, 391715, 255636, 373571, 106435, 252760,
#         69415, 177650,  18392,  85044,  21267,  94065,  89274, 193947,
#        125642, 244648, 278545, 354181, 366672, 399772, 403758, 417092],
#       dtype=int64)

# %%
monthly_member_vs_casual_df['member_casual_percentage'] = ((monthly_member_vs_casual_df['member_casual'].values / monthly_total_trips_2)*100).values
monthly_member_vs_casual_df
# Out:
#                           member_casual  member_casual_percentage
# month_year member_casual
# 2021-08    casual                410012                 51.174419
#            member                391193                 48.825581
# 2021-09    casual                361708                 48.008622
#            member                391715                 51.991378
# 2021-10    casual                255636                 40.628283
#            member                373571                 59.371717
# 2021-11    casual                106435                 29.631537
#            member                252760                 70.368463
# 2021-12    casual                 69415                 28.095845
#            member                177650                 71.904155
# 2022-01    casual                 18392                 17.781043
#            member                 85044                 82.218957
# 2022-02    casual                 21267                 18.439809
# ...

# %% [markdown]
# ### it is percentage of member vs casual monthly

# %%
monthly_member_vs_casual_df_new = monthly_member_vs_casual_df.reset_index(level=['month_year'])
monthly_member_vs_casual_df_new
# Out:
#               month_year  member_casual  member_casual_percentage
# member_casual
# casual           2021-08         410012                 51.174419
# member           2021-08         391193                 48.825581
# casual           2021-09         361708                 48.008622
# member           2021-09         391715                 51.991378
# casual           2021-10         255636                 40.628283
# member           2021-10         373571                 59.371717
# casual           2021-11         106435                 29.631537
# member           2021-11         252760                 70.368463
# casual           2021-12          69415                 28.095845
# member           2021-12         177650                 71.904155
# casual           2022-01          18392                 17.781043
# member           2022-01          85044                 82.218957
# casual           2022-02          21267                 18.439809
# ...

# %%
monthly_member_percentage = monthly_member_vs_casual_df_new[monthly_member_vs_casual_df_new.index == 'member']['member_casual_percentage'].values
monthly_member_percentage
# Out:
# array([48.82558147, 51.99137802, 59.3717171 , 70.36846281, 71.90415478,
#        82.21895665, 81.56019145, 68.47903228, 66.06929704, 55.97699478,
#        52.15932279, 50.81220686])

# %%
monthly_casual_percentage = monthly_member_vs_casual_df_new[monthly_member_vs_casual_df_new.index == 'casual']['member_casual_percentage'].values
monthly_casual_percentage
# Out:
# array([51.17441853, 48.00862198, 40.6282829 , 29.63153719, 28.09584522,
#        17.78104335, 18.43980855, 31.52096772, 33.93070296, 44.02300522,
#        47.84067721, 49.18779314])

# %%
monthly_member_months = monthly_member_vs_casual_df_new[monthly_member_vs_casual_df_new.index == 'member']['month_year'].values
monthly_member_months
# Out:
# array([Period('2021-08', 'M'), Period('2021-09', 'M'),
#        Period('2021-10', 'M'), Period('2021-11', 'M'),
#        Period('2021-12', 'M'), Period('2022-01', 'M'),
#        Period('2022-02', 'M'), Period('2022-03', 'M'),
#        Period('2022-04', 'M'), Period('2022-05', 'M'),
#        Period('2022-06', 'M'), Period('2022-07', 'M')], dtype=object)

# %%
plt.figure(figsize=(20,10))
plt.plot(monthly_member_months.astype('str') ,monthly_member_percentage , label = 'member')
plt.plot(monthly_member_months.astype('str') ,monthly_casual_percentage , label = 'casual')
plt.title('member vs casual')
plt.ylabel("percentage")
plt.xlabel("months")
plt.legend()

# %% [markdown]
# ### A14: as we can see when we was facing problem between 12-2021 ad 03-2022 Almost the trips were from members only and a very small percentage of casual , And we can know how important it is to convert casual into members because this will help the company in times of crisis , also we conclude we normal percentage of members vs casual is 50-50

# %% [markdown]
# ### Q15: is member and casual choose the same type of bike ?

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
tripdata_last_12_months_df.groupby(['member_casual' , 'rideable_type'])['rideable_type'].count()
# Out:
# member_casual  rideable_type
# casual         classic_bike     1125130
#                docked_bike       220185
#                electric_bike    1161441
# member         classic_bike     1920228
#                electric_bike    1455410
# Name: rideable_type, dtype: int64

# %% [markdown]
# ### A15: <br> 1- all docked bike used by casual , so we can benfit from it <br> 2-member using classic bike more than electric bike but casual use both types in roughly the same proportions

# %% [markdown]
# ### Q16 : Arrange the days in terms of the most requested bikes for member and casual

# %%
trips_per_day_for_members = tripdata_last_12_months_df[tripdata_last_12_months_df.member_casual == 'member']['day_of_week'].value_counts().sort_index()
trips_per_day_for_members
# Out:
# 0    471938
# 1    522855
# 2    522175
# 3    522140
# 4    466190
# 5    452939
# 6    417401
# Name: day_of_week, dtype: int64

# %%
trips_per_day_for_members.sort_values()
# Out:
# 6    417401
# 5    452939
# 4    466190
# 0    471938
# 3    522140
# 2    522175
# 1    522855
# Name: day_of_week, dtype: int64

# %%
trips_per_day_for_casual = tripdata_last_12_months_df[tripdata_last_12_months_df.member_casual == 'casual']['day_of_week'].value_counts().sort_index()
trips_per_day_for_casual
# Out:
# 0    297740
# 1    272414
# 2    280441
# 3    314454
# 4    345695
# 5    524016
# 6    471996
# Name: day_of_week, dtype: int64

# %%
trips_per_day_for_casual.sort_values()
# Out:
# 1    272414
# 2    280441
# 0    297740
# 3    314454
# 4    345695
# 6    471996
# 5    524016
# Name: day_of_week, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(trips_per_day_for_members.index , trips_per_day_for_members.values , label = 'members')
plt.plot(trips_per_day_for_casual.index , trips_per_day_for_casual.values , label = 'casual')
plt.legend()
plt.title('number of trips daily for member and causes')
plt.ylabel('number_of_trips')
plt.xlabel('day')
# Out:
# Text(0.5, 0, 'day')

# %% [markdown]
# ### A16: Members use bikes more on work days, but the percentage drops by about 20% on weekends, so we can conclude that most trips go to places they go to daily, such as university or work And of course we can benefit from that
# ### As for casual, their demand is few on working days, approximately twenty-five thousand per day, but on weekends the number doubles and the percentage of increase in casual is more than the decrease in demand from members

# %% [markdown]
# ### Q17: Most and least demand hours for member and casual

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
hour_of_day_members = tripdata_last_12_months_df[tripdata_last_12_months_df.member_casual == 'member']['hour_of_day'].value_counts().sort_index()
hour_of_day_members
# Out:
# 0      36208
# 1      22790
# 2      13121
# 3       7937
# 4       9157
# 5      33935
# 6      90714
# 7     172551
# 8     203028
# 9     146971
# 10    140307
# 11    168495
# 12    194459
# 13    190927
# 14    187900
# 15    220770
# 16    289692
# 17    350552
# 18    289239
# 19    207064
# 20    145011
# 21    111848
# 22     85535
# 23     57427
# Name: hour_of_day, dtype: int64

# %%
hour_of_day_members.sort_values()
# Out:
# 3       7937
# 4       9157
# 2      13121
# 1      22790
# 5      33935
# 0      36208
# 23     57427
# 22     85535
# 6      90714
# 21    111848
# 10    140307
# 20    145011
# 9     146971
# 11    168495
# 7     172551
# 14    187900
# 13    190927
# 12    194459
# 8     203028
# 19    207064
# 15    220770
# 18    289239
# 16    289692
# 17    350552
# Name: hour_of_day, dtype: int64

# %%
hour_of_day_casual = tripdata_last_12_months_df[tripdata_last_12_months_df.member_casual == 'casual']['hour_of_day'].value_counts().sort_index()
hour_of_day_casual
# Out:
# 0      50719
# 1      34358
# 2      21981
# 3      12709
# 4       9215
# 5      13236
# 6      28310
# 7      52554
# 8      70175
# 9      78212
# 10    103917
# 11    134862
# 12    158067
# 13    167578
# 14    174578
# 15    190297
# 16    208166
# 17    235249
# 18    211996
# 19    163537
# 20    119918
# 21    102453
# 22     94026
# 23     70643
# Name: hour_of_day, dtype: int64

# %%
hour_of_day_casual.sort_values()
# Out:
# 4       9215
# 3      12709
# 5      13236
# 2      21981
# 6      28310
# 1      34358
# 0      50719
# 7      52554
# 8      70175
# 23     70643
# 9      78212
# 22     94026
# 21    102453
# 10    103917
# 20    119918
# 11    134862
# 12    158067
# 19    163537
# 13    167578
# 14    174578
# 15    190297
# 16    208166
# 18    211996
# 17    235249
# Name: hour_of_day, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.plot(hour_of_day_members.index , hour_of_day_members.values , label = 'members')
plt.plot(hour_of_day_casual.index , hour_of_day_casual.values , label = 'casual')
plt.legend()
plt.title('number of trips hourly for member and causes')
plt.ylabel('number_of_trips')
plt.xlabel('hour')
# Out:
# Text(0.5, 0, 'hour')

# %% [markdown]
# ### A17: for hours i see no difference between members and casual , the main difference for me in days

# %% [markdown]
# ### Q18 : mean of duration of trip for member and casual

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
tripdata_last_12_months_df[tripdata_last_12_months_df.member_casual == 'member']['duration_trip'].mean()
# Out:
# Timedelta('0 days 00:12:18.758754641')

# %%
tripdata_last_12_months_df[tripdata_last_12_months_df.member_casual == 'casual']['duration_trip'].mean()
# Out:
# Timedelta('0 days 00:22:04.124322829')

# %%
tripdata_last_12_months_df['duration_trip'].mean()
# Out:
# Timedelta('0 days 00:16:28.209684016')

# %% [markdown]
# ### on any day of the week mean of duration is 16 minute and 28 seconds <br> but for member only mean is 12 minute , and for casual mean is 22 minute <br> so there is a differnce of duration time between member and casual

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
clark_member_casual_valuecounts = tripdata_last_12_months_df[tripdata_last_12_months_df.start_station_name == 'Clark St & Wrightwood Ave']['member_casual'].value_counts()
clark_member_casual_valuecounts
# Out:
# member    15559
# casual    11299
# Name: member_casual, dtype: int64

# %%
(clark_member_casual_valuecounts.values / sum(clark_member_casual_valuecounts.values) * 100)
# Out:
# array([57.93059796, 42.06940204])

# %% [markdown]
# ### 58% of people start a trip from this station are member

# %% [markdown]
# ### ِObservation summary for questions from 13 to 19
# * PART 1
#  * mean of ratio for member and casual is 57% members and 42% casuals (q13)
#  * when company was facing issues between 12-2021 ad 03-2022 more than 80% of trips was from members and only less than 20% from casuals (q14)
#  * Here the importance of members in crises appears
#
# * PART 2 (VIP)
#  * all users use docked bikes are casual (q15)
#  * members using classic bikes more than electric bikes (60 to 40) (q15)
#
# * PART 3 -1 (VIP)
#  * Members use bikes more on work days, but the percentage drops by about 20% on weekends, so we can conclude that there are 2 types of member (q16)
#   * 1- Members joined us to go to work or university daily and do not use the membership on weekends
#   * 2- Members joined us to go to work or university daily and use the membership on weekends
#   * Of course, we can benefit from that, as we will explain in the recommendations section
#
# * PART 3 -2 (VIP)
#  * As for casual, their demand is few on working days, approximately twenty-five thousand per day, but on weekends the number doubles and the percentage of increase in casual is more than the decrease in demand from members , And we can conclude A large percentage from causal only get trips on weekends Of course, we can benefit from that, as we will explain in the recommendations section  (q16)
#
# * PART 4 (VIP)
#  *  on any day of the week mean of duration is 16 minute and 28 seconds but for member only mean is 12 minute , and for casual mean is 22 minute so there is a differnce of duration time between member and casual  (q18)

# %% [markdown]
# ### recommendations (from questions 13 to 19)
# * From Part 1 We suggest that the company's priority should be to increase the number of members
# * From Part 2 we recommend that the company create new plan or membership for docked bikes
# * From PART 3 we recomend that make more than membership
#  * full-membership: all days in week
#  * business-membership: business day in week (monday to friday)
#  * weekend-membership: weekends only and Official vacations (saturday and sunday)
#  * docked-membeship: membership for docked bikes (From Part 2)
#
# * From Part 4 The members' trip duration is less than the casuals, almost half, so we conclude that the members want more speed, so in the advertising campaigns we will focus on the advantage of speed and safety in all memberships except for the weekend memberships

# %% [markdown]
# ## All Observations Summary

# %% [markdown]
# ### ِObservation from all 12 question above before start on main goal (from questions 1 to 12)
#
# * PART 1
#  * Mean of Duration increasing in Saturday and Sunday (Q2)
#  * Also Total number of trips increasing In Saturday and sunday (Q5)
#  * saturday and sunday is not business days in USA so we can conclude that a lot of people using bikes more in weekends And we can take advantage of that
#
# * PART 2
#  * Highest time people start trips between 13-19 in all days but in business days 12-17 was highest time and the difference between these five hours and the reset of day inceased  (Q7)
#  * We can conclude that the time when employees leave work is the most demanding time on working days, and we can benefit from that
#
# * PART 3
#  * total number of trips and mean of duration was in lowest level between these months from 12-2021 to 03-2022 so we was facing a problem in this time
#
#  ### ِObservation summary for questions from 13 to 19
# * PART 1
#  * mean of ratio for member and casual is 57% members and 42% casuals (q13)
#  * when company was facing issues between 12-2021 ad 03-2022 more than 80% of trips was from members and only less than 20% from casuals (q14)
#  * Here the importance of members in crises appears
#
# * PART 2 (VIP)
#  * all users use docked bikes are casual (q15)
#  * members using classic bikes more than electric bikes (60 to 40) (q15)
#
# * PART 3 -1 (VIP)
#  * Members use bikes more on work days, but the percentage drops by about 20% on weekends, so we can conclude that there are 2 types of member (q16)
#   * 1- Members joined us to go to work or university daily and do not use the membership on weekends
#   * 2- Members joined us to go to work or university daily and use the membership on weekends
#   * Of course, we can benefit from that, as we will explain in the recommendations section
#
# * PART 3 -2 (VIP)
#  * As for casual, their demand is few on working days, approximately twenty-five thousand per day, but on weekends the number doubles and the percentage of increase in casual is more than the decrease in demand from members , And we can conclude A large percentage from causal only get trips on weekends Of course, we can benefit from that, as we will explain in the recommendations section  (q16)
#
# * PART 4 (VIP)
#  *  on any day of the week mean of duration is 16 minute and 28 seconds but for member only mean is 12 minute , and for casual mean is 22 minute so there is a differnce of duration time between member and casual  (q18)

# %% [markdown]
# ## All Recommendations Summary

# %% [markdown]
# ### recommendations (from questions 1 to 12)
#
# * (From Part 1) If we want to run an advertising campaign to increase users, we can target people who want to go out on weekend days and also add a reservation feature to them if they want to make sure that they have a bike before going out and offers for couples
#
# * (From Part 2) Increasing the number of stations close to workplaces and increasing the number of rentable bikes available in these stations, especially at the time of employees’ departure. It is possible to make special offers for employees or go to companies and make contracts with them if they want to provide employees with special packages for those who work for them
#
# * (From Part 1 and 2) To increase efficiency in the future, it is possible to differentiate between stations that are more directed to employees or working days and other stations that are directed to people who start trips on weekends. After determining the types of stations, we will transfer the largest number of bikes to stations designated for employees on working days, either Weekends we will transfer bikes to other stations directed on holidaysTo increase efficiency in the future, it is possible to differentiate between stations that are more directed to employees or working days and other stations that are directed to people who start trips on weekends. After determining the types of stations, we will transfer the largest number of bikes to stations designated for employees on working days, either Weekends we will transfer bikes to other stations directed on holidays
#
# ### recommendations (from questions 13 to 19)
# * From Part 1 We suggest that the company's priority should be to increase the number of members
# * From Part 2 we recommend that the company create new plan or membership for docked bikes
# * From PART 3 we recomend that make more than membership
#  * full-membership: all days in week
#  * business-membership: business day in week (monday to friday)
#  * weekend-membership: weekends only and Official vacations (saturday and sunday)
#  * docked-membeship: membership for docked bikes (From Part 2)
#
# * From Part 4 The members' trip duration is less than the casuals, almost half, so we conclude that the members want more speed, so in the advertising campaigns we will focus on the advantage of speed and safety in all memberships except for the weekend memberships

# %% [markdown]
# ### Save Data

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
tripdata_last_12_months_df.to_csv('saved_data/trip_data_last_12_months.csv')

# %%
tripdata_last_12_months_df
# Out:
#                   ride_id  rideable_type          started_at  \
# 0        D6AC43863387B96A   classic_bike 2021-08-01 00:00:04
# 1        00015E7CD37F64C4   classic_bike 2021-08-01 00:00:17
# 2        3B9554C394136D13   classic_bike 2021-08-01 00:00:19
# 3        3F35D7C35A1DB902   classic_bike 2021-08-01 00:00:27
# 4        A39DD0D9AD715E27   classic_bike 2021-08-01 00:00:32
# ...                   ...            ...                 ...
# 5882389  E77BC768DD3C65C4  electric_bike 2022-07-31 23:58:58
# 5882390  B8DE5E943AE3139E  electric_bike 2022-07-31 23:58:58
# 5882391  9D9B50749D946176   classic_bike 2022-07-31 23:59:05
# 5882392  BE56236D4E602A10   classic_bike 2022-07-31 23:59:29
# 5882393  1715A3889F15156C  electric_bike 2022-07-31 23:59:58
#
#                    ended_at               start_station_name start_station_id  \
# 0       2021-08-01 00:13:28        Clark St & Wrightwood Ave     TA1305000014
# ...

# %%
tripdata_last_12_months_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5882394 entries, 0 to 5882393
# Data columns (total 17 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  month_year          period[M]
#  14  duration_trip       timedelta64[ns]
#  15  day_of_week         int64
#  16  hour_of_day         int64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(7), period[M](1), timedelta64[ns](1)
# memory usage: 762.9+ MB
